# %% [markdown]
# #### Imports

# %%
import os
from pyspark.mllib.recommendation import ALS
import math

# %% [markdown]
# ### Loading the Netflix dataset

# %%
netflix_dataset_path = "./../../Datasets/Netflix-prize-data/"

# %%
combined_data_1_location = os.path.join(netflix_dataset_path, "combined_data_1.txt")
combined_data_2_location = os.path.join(netflix_dataset_path, "combined_data_2.txt")
combined_data_3_location = os.path.join(netflix_dataset_path, "combined_data_3.txt")
combined_data_4_location = os.path.join(netflix_dataset_path, "combined_data_4.txt")

help_location = f'{combined_data_1_location},{combined_data_2_location},{combined_data_3_location},{combined_data_4_location}'

# %% [markdown]
# Combine all data to the same sark context:

# %%
combined_data = sc.textFile(help_location).cache()

# %%
print(f'There are {combined_data.count()} elements in the combined RDD')
# Out:
# There are 100498277 elements in the combined RDD

# %% [markdown]
# The available data represent a movie id, followed by many reviews from different users. We wish to structure the data and group them by each individual user, since our target is to predict the rating that each user would assign to a movie. The following example shows that for the movied with id 1, the user with id 1488844 has rated it with 3 stars out of 5, with the rating date to be the 6th of Spetmeber, 2005. The next lines follow the same pattern, until all reviews are exhausted and then a single line with the number '2:' will show up, followed by the corresponding reviews for the second movie etc.

# %% [markdown]
# In order to efficiently perform the Alternating Least Squares algorith, we will need to re-map the form of these lines into the pattern 'user_id, movie_id, rating'. We do not care about the date of the ratings, since we do not intend to use them in our model.

# %% [markdown]
# #### Spark transformations

# %% [markdown]
# Remove the dates of ratings from the data:

# %%
def remove_dates(single_line):
    """
    Removes the date of reviews. 
    
    Inputs:
        single line -> A single line of the original RDD, represented as a list fo strings.
        
    Outputs:
        new_line -> A list of strings without the date. 
        
    We need to take special care of the lines that represent a movie id, which only have a single element 
    in their list representation.
    """
    
    if len(single_line)==1:
        return single_line
    else:
        return single_line[:-1]

# %%
no_dates_rdd = combined_data.map(lambda line: line.split(",")).map(lambda lst: remove_dates(lst)).cache()

# %%
no_dates_rdd.take(10)
# Out:
# [['1:'],
#  ['1488844', '3'],
#  ['822109', '5'],
#  ['885013', '4'],
#  ['30878', '4'],
#  ['823519', '3'],
#  ['893988', '3'],
#  ['124105', '4'],
#  ['1248029', '3'],
#  ['1842128', '4']]

# %% [markdown]
# #### Assign a movie id to the rating

# %%
def append_acc(file_path, acc):
    
    movie_id = -1
    with open(file_path, 'r') as cd:
        for line in cd:
            if ':' in line:
                movie_id = line.split(':')[0]
            else:
                acc.append(movie_id)
    
    return acc

# %%
acc = append_acc(combined_data_1_location, [])
acc = append_acc(combined_data_2_location, acc)
acc = append_acc(combined_data_3_location, acc)
acc = append_acc(combined_data_4_location, acc)

# %%
len(acc)
# Out:
# 100480507

# %% [markdown]
# From inspecting the 'combined_data_1.txt' file we can see that the movie id 2 is found in line 549. Taking into account that lines are indexed from number 1, and the first line contains the movie id 1, we expect to meet 547 reviews for the movie with id 1. furthermore, we expect to see that the 547th review is about the movie with id 2.

# %%
acc[546]
# Out:
# '1'

# %%
acc[547]
# Out:
# '2'

# %% [markdown]
# In order to be completely sure that no mistake was made, we check if there is an unexpected value to the first 546 elements

# %%
def find_unexpected(lst, correct_elem):
    """
    Finds if an unexpected element is found among elem in a list.
    
    Inputs:
        lst -> The list under consideration.
        elem -> The expected element to the list.
        
    Returns:
        None
        
    Outputs:
        A message of correctness or not.
    """
    
    for index, elem in enumerate(lst):
        if elem!=correct_elem:
            print(f'Found unexpected element: {elem} in position {index}')
            return
                  
    print("No unexpected element was found!")

# %%
find_unexpected(acc[:547], '1')
# Out:
# No unexpected element was found!

# %%
find_unexpected(acc[:548], '1')
# Out:
# Found unexpected element: 2 in position 547

# %% [markdown]
# Remove the movie id elements fromm the RDD

# %%
no_movie_ids_rdd = no_dates_rdd.filter(lambda elem: ':' not in elem[0]).cache()

# %% [markdown]
# We need to ensure that the number of elements in this RDD is the same with the number of elements in the accumulator:

# %%
no_movie_ids_rdd.count()
# Out:
# 100480507

# %%
no_movie_ids_rdd.take(5)
# Out:
# [['1488844', '3'],
#  ['822109', '5'],
#  ['885013', '4'],
#  ['30878', '4'],
#  ['823519', '3']]

# %% [markdown]
# Since it is the same, we can proceed to the next steps!

# %% [markdown]
# Zip the RDDs with their index:

# %%
indexed_rdd = no_movie_ids_rdd.zipWithIndex().cache()

# %%
indexed_rdd.count()
# Out:
# 100480507

# %%
indexed_rdd.take(5)
# Out:
# [(['1488844', '3'], 0),
#  (['822109', '5'], 1),
#  (['885013', '4'], 2),
#  (['30878', '4'], 3),
#  (['823519', '3'], 4)]

# %% [markdown]
# Now we can use the accumulator along with the indexes to assign a movie ID to each review, in the form of
# (user_id, movie_id, rating):

# %%
joint_rdd = indexed_rdd.map(lambda tpl: (int(tpl[0][0]), int(acc[tpl[1]]), int(tpl[0][1]))).cache()

# %%
joint_rdd.count()
# Out:
# 100480507

# %%
joint_rdd.take(5)
# Out:
# [(1488844, 1, 3),
#  (822109, 1, 5),
#  (885013, 1, 4),
#  (30878, 1, 4),
#  (823519, 1, 3)]

# %% [markdown]
# Next step is to reorganize the reviews based on the user id. First we need to create a key-value pair schema:

# %%
key_value_schema = joint_rdd.map(lambda elem: (elem[0], (elem[1], elem[2]))).cache()

# %%
key_value_schema.count()
# Out:
# 100480507

# %%
key_value_schema.take(5)
# Out:
# [(1488844, (1, 3)),
#  (822109, (1, 5)),
#  (885013, (1, 4)),
#  (30878, (1, 4)),
#  (823519, (1, 3))]

# %% [markdown]
# No we just need to sort by value and revert to the required form:

# %%
sorted_rdd = key_value_schema.sortByKey().cache()

# %%
sorted_rdd.count()
# Out:
# 100480507

# %%
sorted_rdd.take(5)
# Out:
# [(6, (30, 3)), (6, (157, 3)), (6, (173, 4)), (6, (175, 5)), (6, (191, 2))]

# %% [markdown]
# Restore the sorted rdd in the requested format:

# %%
final_rdd = sorted_rdd.map(lambda elem: (elem[0], elem[1][0], elem[1][1])).cache()

# %%
final_rdd.count()
# Out:
# 100480507

# %%
final_rdd.take(5)
# Out:
# [(6, 30, 3), (6, 157, 3), (6, 173, 4), (6, 175, 5), (6, 191, 2)]

# %% [markdown]
# ## Alternating Least Squares in the Netflix Dataset

# %% [markdown]
# We split the data in a training, validation and test set. We have a huge number of data, so the split will be performed in 80%-10%-10% ratio respectively.

# %%
training_set, validation_set, test_set = final_rdd.randomSplit([8,1,1], seed= 400)

# %%
training_set.take(5)
# Out:
# [(6, 30, 3), (6, 175, 5), (6, 191, 2), (6, 197, 3), (6, 241, 3)]

# %%
validation_set.take(5)
# Out:
# [(6, 564, 4), (6, 658, 3), (6, 825, 3), (6, 1145, 3), (6, 1180, 3)]

# %%
test_set.take(5)
# Out:
# [(6, 157, 3), (6, 173, 4), (6, 445, 3), (6, 501, 3), (6, 705, 3)]

# %% [markdown]
# We also need to have a second instance of the validation and test sets without their ratings, so that we can predict the reviews and compare with the real ones:

# %%
validation_set_to_predict = validation_set.map(lambda elem: (elem[0], elem[1]))
test_set_to_predict = test_set.map(lambda elem: (elem[0], elem[1]))

# %% [markdown]
# #### Setting a handful of training parameters:

# %%
iterations = 10
regularization_parameters = [0.01, 0.05, 0.1]
ranks = [2, 4, 6, 8, 10, 12]

# %%
min_error = 1e3
best_rank = -1
best_regularization = -1

# %%
for rank in ranks:
    
    for regularization_parameter in regularization_parameters:
    
        model = ALS.train(training_set, rank, seed=5, iterations=iterations,
                          lambda_=regularization_parameter)
        predictions = model.predictAll(validation_set_to_predict).map(lambda elem: ((elem[0], elem[1]), elem[2]))
        true_and_predicted_rates = validation_set.map(lambda elem: ((int(elem[0]), int(elem[1])), float(elem[2]))).join(predictions)
        error = math.sqrt(true_and_predicted_rates.map(lambda elem: (elem[1][0] - elem[1][1])**2).mean())
        print('--------------------------------------')
        print (f'For rank {rank} and amount of regularization {regularization_parameter} the RMSE is {error}')
        if error < min_error:
            min_error = error
            best_rank = rank
            best_regularization = regularization_parameter
# Out:
# --------------------------------------
# For rank 2 and amount of regularization 0.01 the RMSE is 0.88697628814868
# --------------------------------------
# For rank 2 and amount of regularization 0.05 the RMSE is 0.8871776166390885
# --------------------------------------
# For rank 2 and amount of regularization 0.1 the RMSE is 0.8914959584054967
# --------------------------------------
# For rank 4 and amount of regularization 0.01 the RMSE is 0.8681876907047872
# --------------------------------------
# For rank 4 and amount of regularization 0.05 the RMSE is 0.8672640338039733
# --------------------------------------
# For rank 4 and amount of regularization 0.1 the RMSE is 0.8753160642908002
# --------------------------------------
# For rank 6 and amount of regularization 0.01 the RMSE is 0.8596104071174606
# --------------------------------------
# For rank 6 and amount of regularization 0.05 the RMSE is 0.8561725042723435
# --------------------------------------
# For rank 6 and amount of regularization 0.1 the RMSE is 0.867259835236369
# --------------------------------------
# For rank 8 and amount of regularization 0.01 the RMSE is 0.8542283449535314
# --------------------------------------
# For rank 8 and amount of regularization 0.05 the RMSE is 0.8494497358423603
# --------------------------------------
# For rank 8 and amount of regularization 0.1 the RMSE is 0.8637266575960195
# --------------------------------------
# For rank 10 and amount of regularization 0.01 the RMSE is 0.8510548679330673
# --------------------------------------
# For rank 10 and amount of regularization 0.05 the RMSE is 0.8460095461705648
# --------------------------------------
# For rank 10 and amount of regularization 0.1 the RMSE is 0.8633712622968658
# --------------------------------------
# For rank 12 and amount of regularization 0.01 the RMSE is 0.850052890919098
# --------------------------------------
# For rank 12 and amount of regularization 0.05 the RMSE is 0.8419584738869198

# %% [markdown]
# #### Test the model's RMSE performance in the test set.

# %%
model = ALS.train(training_small_ratings, best_rank, seed=5, iterations=iterations,
                  lambda_=best_regularization)
test_set_predictions = model.predictAll(test_set_to_predict).map(lambda r: ((elem[0], elem[1]), elem[2]))
test_set_true_and_predicted_rates = test_set.map(lambda elem: ((int(elem[0]), int(elem[1])), float(elem[2]))).join(test_set_predictions)
test_set_error = math.sqrt(rates_and_preds.map(lambda r: (r[1][0] - r[1][1])**2).mean())

# %%
print(f'Test set RMSE performance: {test_set_error}')

# %% [markdown]
# ## Generate predictions for new users

# %%
# !ls ../../Datasets/Netflix-prize-data/
# Out:
# README.md           combined_data_2.txt combined_data_4.txt probe.txt
# combined_data_1.txt combined_data_3.txt movie_titles.csv    qualifying.txt

# %%
movies_path = os.path.join(netflix_dataset_path, 'movie_titles.csv')
movies = sc.textFile(movies_path)

# %%
movies.take(5)
# Out:
# ['1,2003,Dinosaur Planet',
#  '2,2004,Isle of Man TT 2004 Review',
#  '3,1997,Character',
#  "4,1994,Paula Abdul's Get Up & Dance",
#  '5,2004,The Rise and Fall of ECW']

# %% [markdown]
# Re-arrange to format movie_id, title, year:

# %%
movies = movies.map(lambda temp: temp.split(",")).map(lambda movie: [movie[0], movie[2], movie[1]])

# %%
movies.take(5)
# Out:
# [['1', 'Dinosaur Planet', '2003'],
#  ['2', 'Isle of Man TT 2004 Review', '2004'],
#  ['3', 'Character', '1997'],
#  ['4', "Paula Abdul's Get Up & Dance", '1994'],
#  ['5', 'The Rise and Fall of ECW', '2004']]

# %% [markdown]
# Now we need to get the average ratings of the movies, based on the user reviews:

# %%
def avg(lst):
    
    return sum(lst)/len(lst)

# %%
movie_and_ratings_temp = \
    final_rdd.map(lambda elem: (elem[1], elem[2])).groupByKey()

# %%
movie_and_ratings_temp.count()
# Out:
# 17770

# %%
movie_and_ratings_temp.take(1)
# Out:
# [(4914, <pyspark.resultiterable.ResultIterable at 0x111ab9cc0>)]

# %%
movie_and_ratings_temp1 = movie_and_ratings_temp.map(lambda elem: (elem[0], list(elem[1])))

# %%
movie_and_ratings_temp1.take(1)
# Out:
# [(4914,
#   [4,
#    4,
#    3,
#    4,
#    4,
#    2,
#    2,
#    4,
#    4,
#    5,
#    3,
#    3,
#    1,
#    3,
#    3,
#    4,
#    3,
#    3,
#    3,
#    3,
#    4,
#    2,
#    3,
#    3,
#    4,
#    3,
#    3,
#    4,
#    3,
#    1,
#    4,
#    2,
#    2,
#    4,
#    3,
#    4,
#    4,
#    2,
#    4,
#    3,
#    5,
#    3,
#    2,
#    4,
#    4,
#    4,
#    4,
#    3,
#    5,
#    4,
#    4,
#    2,
#    2,
#    5,
#    4,
#    3,
#    4,
#    2,
#    5,
#    4,
#    3,
#    1,
#    4,
#    3,
#    3,
#    3,
#    2,
#    4,
#    4,
#    3,
#    2,
#    4,
#    4,
#    3,
#    4,
#    5,
#    3,
#    4,
#    2,
#    2,
#    3,
#    3,
#    3,
#    3,
#    2,
#    3,
#    4,
#    5,
#    2,
#    5,
#    3,
#    5,
#    3,
#    3,
#    2,
#    3,
#    2,
#    2,
#    4,
#    2,
#    4,
#    3,
#    4,
#    4,
#    3,
#    3,
#    3,
#    4,
#    3,
#    2,
#    2,
#    4,
#    3,
#    3,
#    5,
#    1,
#    4,
#    5,
#    3,
#    3,
#    4,
#    1,
#    3,
#    3,
#    3,
#    4,
#    3,
#    5,
#    4,
#    3,
#    3,
#    3,
#    2,
#    3,
#    2,
#    3,
#    3,
#    4,
#    4,
#    3,
#    4,
#    5,
#    5,
#    3,
#    2,
#    4,
#    3,
#    1,
#    3,
#    4,
#    1,
#    4,
#    3,
#    3,
#    4,
#    3,
#    3,
#    5,
#    4,
#    3,
#    2,
#    3,
#    4,
#    4,
#    1,
#    2,
#    4,
#    3,
#    2,
#    2,
#    2,
#    3,
#    3,
#    2,
#    3,
#    3,
#    3,
#    4,
#    1,
#    3,
#    3,
#    4,
#    4,
#    4,
#    3,
#    4,
#    3,
#    3,
#    4,
#    3,
#    4,
#    4,
#    4,
#    2,
#    5,
#    2,
#    3,
#    1,
#    3,
#    2,
#    3,
#    3,
#    4,
#    4,
#    4,
#    5,
#    5,
#    2,
#    2,
#    4,
#    2,
#    5,
#    4,
#    3,
#    3,
#    4,
#    3,
#    3,
#    4,
#    3,
#    4,
#    3,
#    2,
#    4,
#    4,
#    2,
#    4,
#    2,
#    2,
#    3,
#    3,
#    3,
#    2,
#    3,
#    1,
#    2,
#    2,
#    2,
#    3,
#    3,
#    3,
#    4,
#    4,
#    4,
#    2,
#    2,
#    5,
#    5,
#    1,
#    3,
#    2,
#    3,
#    3,
#    2,
#    3,
#    3,
#    1,
#    3,
#    3,
#    3,
#    2,
#    5,
#    5,
#    2,
#    4,
#    3,
#    3,
#    3,
#    3,
#    3,
#    4,
#    2,
#    3,
#    2,
#    4,
#    3,
#    3,
#    4,
#    3,
#    2,
#    3,
#    4,
#    3,
#    5,
#    2,
#    4,
#    5,
#    3,
#    2,
#    3,
#    2,
#    4,
#    4,
#    3,
#    3,
#    1,
#    3,
#    4,
#    1,
#    3,
#    3,
#    3,
#    3,
#    2,
#    3,
#    4,
#    3,
#    3,
#    3,
#    4,
#    4,
#    3,
#    3,
#    2,
#    3,
#    4,
#    5,
#    3,
#    3,
#    5,
#    2,
#    3,
#    1,
#    4,
#    3,
#    2,
#    4,
#    3,
#    2,
#    3,
#    4,
#    4,
#    4,
#    4,
#    2,
#    3,
#    1,
#    3,
#    3,
#    3,
#    2,
#    4,
#    2,
#    3,
#    3,
#    4,
#    1,
#    4,
#    3,
#    2,
#    2,
#    2,
#    3,
#    3,
#    1,
#    5,
#    3,
#    3,
#    2,
#    1,
#    2,
#    3,
#    2,
#    4,
#    5,
#    4,
#    4,
#    3,
#    4,
#    3,
#    3,
#    1,
#    2,
#    1,
#    4,
#    2,
#    3,
#    4,
#    4,
#    4,
#    1,
#    2,
#    3,
#    3,
#    3,
#    3,
#    2,
#    2,
#    2,
#    4,
#    3,
#    4,
#    4,
#    5,
#    2,
#    4,
#    1,
#    2,
#    3,
#    4,
#    3,
#    3,
#    4,
#    4,
#    4,
#    1,
#    3,
#    3,
#    2,
#    3,
#    3,
#    3,
#    4,
#    2,
#    3,
#    3,
#    3,
#    3,
#    4,
#    4,
#    2,
#    3,
#    2,
#    3,
#    3,
#    3,
#    3,
#    3,
#    2,
#    5,
#    2,
#    3,
#    2,
#    3,
#    5,
#    3,
#    2,
#    4,
#    5,
#    4,
#    4,
#    3,
#    2,
#    3,
#    4,
#    3,
#    4,
#    3,
#    3,
#    2,
#    3,
#    4,
#    4,
#    4,
#    3,
#    5,
#    4,
#    4,
#    2,
#    2,
#    4,
#    3,
#    3,
#    5,
#    4,
#    4,
#    3,
#    3,
#    3,
#    3,
#    3,
#    4,
#    4,
#    3,
#    4,
#    2,
#    4,
#    4,
#    3,
#    3,
#    5,
#    3,
#    3,
#    3,
#    1,
#    5,
#    2,
#    3,
#    5,
#    3,
#    3,
#    3,
#    4,
#    2,
#    2,
#    3,
#    2,
#    3,
#    4,
#    1,
#    2,
#    3,
#    3,
#    3,
#    3,
#    5,
#    2,
#    4,
#    3,
#    3,
#    3,
#    4,
#    3,
#    1,
#    2,
#    4,
#    4,
#    4,
#    3,
#    3,
#    4,
#    4,
#    3,
#    1,
#    3,
#    3,
#    2,
#    3,
#    3,
#    1,
#    3,
#    4,
#    3,
#    3,
#    3,
#    4,
#    3,
#    4,
#    3,
#    3,
#    4,
#    3,
#    3,
#    5,
#    2,
#    3,
#    4,
#    3,
#    3,
#    3,
#    5,
#    3,
#    4,
#    3,
#    3,
#    4,
#    3,
#    3,
#    2,
#    5,
#    4,
#    5,
#    2,
#    3,
#    3,
#    2,
#    3,
#    3,
#    3,
#    4,
#    3,
#    2,
#    3,
#    5,
#    2,
#    4,
#    4,
#    4,
#    4,
#    4,
#    3,
#    3,
#    5,
#    2,
#    3,
#    3,
#    3,
#    2,
#    3,
#    3,
#    4,
#    4,
#    3,
#    4,
#    3,
#    4,
#    2,
#    4,
#    2,
#    3,
#    3,
#    3,
#    5,
#    4,
#    4,
#    1,
#    4,
#    3,
#    2,
#    4,
#    2,
#    4,
#    4,
#    4,
#    5,
#    1,
#    3,
#    2,
#    3,
#    2,
#    3,
#    4,
#    4,
#    4,
#    2,
#    4,
#    3,
#    3,
#    2,
#    4,
#    3,
#    3,
#    5,
#    4,
#    3,
#    4,
#    3,
#    3,
#    4,
#    2,
#    3,
#    3,
#    2,
#    3,
#    1,
#    3,
#    3,
#    2,
#    3,
#    4,
#    4,
#    4,
#    4,
#    4,
#    3,
#    3,
#    3,
#    3,
#    3,
#    3,
#    3,
#    4,
#    2,
#    3,
#    4,
#    4,
#    3,
#    3,
#    3,
#    2,
#    2,
#    3,
#    3,
#    2,
#    3,
#    3,
#    1,
#    3,
#    4,
#    3,
#    2,
#    4,
#    3,
#    3,
#    3,
#    3,
#    5,
#    3,
#    3,
#    2,
#    3,
#    2,
#    5,
#    3,
#    4,
#    3,
#    5,
#    3,
#    3,
#    4,
#    2,
#    3,
#    3,
#    3,
#    3,
#    4,
#    4,
#    3,
#    4,
#    4,
#    2,
#    3,
#    4,
#    4,
#    1,
#    2,
#    2,
#    3,
#    4,
#    4,
#    4,
#    3,
#    3,
#    4,
#    2,
#    4,
#    3,
#    3,
#    1,
#    3,
#    3,
#    4,
#    3,
#    4,
#    5,
#    3,
#    1,
#    3,
#    4,
#    4,
#    5,
#    4,
#    3,
#    3,
#    3,
#    4,
#    3,
#    3,
#    3,
#    3,
#    1,
#    5,
#    3,
#    3,
#    2,
#    4,
#    2,
#    3,
#    3,
#    4,
#    3,
#    4,
#    1,
#    4,
#    4,
#    3,
#    3,
#    3,
#    1,
#    4,
#    3,
#    4,
#    3,
#    4,
#    4,
#    3,
#    4,
#    2,
#    4,
#    5,
#    3,
#    2,
#    2,
#    1,
#    4,
#    4,
#    1,
#    4,
#    3,
#    4,
#    3,
#    3,
#    5,
#    3,
#    3,
#    4,
#    3,
#    2,
#    4,
#    3,
#    3,
#    3,
#    2,
#    3,
#    3,
#    3,
#    1,
#    3,
#    3,
#    3,
#    2,
#    3,
#    4,
#    3,
#    3,
#    1,
#    3,
#    3,
#    4,
#    3,
#    3,
#    4,
#    4,
#    1,
#    2,
#    3,
#    4,
#    4,
#    3,
#    3,
#    1,
#    3,
#    3,
#    2,
#    3,
#    3,
#    3,
#    2,
#    3,
#    4,
#    5,
#    3,
#    4,
#    3,
#    4,
#    4,
#    3,
#    5,
#    3,
#    1,
#    2,
#    3,
#    3,
#    5,
#    1,
#    5,
#    5,
#    5,
#    2,
#    4,
#    3,
#    3,
#    2,
#    3,
#    3,
#    3,
#    3,
#    4,
#    5,
#    5,
#    3,
#    2,
#    4,
#    3,
#    3,
#    4,
#    3,
#    3,
#    4,
#    1,
#    2,
#    3,
#    3,
#    3,
#    4,
#    2,
#    4,
#    4,
#    3,
#    2,
#    3,
#    4,
#    2,
#    4,
#    3,
#    4,
#    5,
#    4,
#    4,
#    3,
#    4,
#    1,
#    3,
#    2,
#    1,
#    2,
#    1,
#    2,
#    4,
#    2,
#    3,
#    1,
#    3,
#    4,
#    4,
#    5,
#    3,
#    5,
#    2,
#    2,
#    3,
#    3,
#    2,
#    4,
#    3,
#    3,
#    5,
#    4,
#    2,
#    5,
#    4,
#    3,
#    2,
#    5,
#    2,
#    4,
#    2,
#    1,
#    3,
#    3,
#    5,
#    2,
#    3,
#    2,
#    4,
#    2,
#    3,
#    2,
#    2,
#    3,
#    3,
#    4,
#    4,
#    5,
#    3,
#    2,
#    2,
#    4,
#    2,
#    4,
#    4,
#    4,
#    4,
#    3,
#    3,
#    2,
#    3,
#    5,
#    1,
#    2,
#    4,
#    3,
#    4,
#    3,
#    1,
#    3,
#    4,
#    2,
#    5,
#    3,
#    4,
#    4,
#    3,
#    5,
#    3,
#    4,
#    2,
#    3,
#    3,
#    5,
#    4,
#    2,
#    3,
#    4,
#    3,
#    2,
#    4,
#    3,
#    4,
#    3,
#    ...])]

# %% [markdown]
# We then create a new RDD that contains the same values as in the form of ( movie_id, (average_review, number_of_reviewers) )

# %%
movie_and_ratings = movie_and_ratings_temp1.map(lambda elem: (int(elem[0]), (avg(elem[1]), len(elem[1]))))

# %%
movie_and_ratings.take(5)
# Out:
# [(4914, (3.1278435059677716, 38289)),
#  (5607, (3.4454226399381356, 16811)),
#  (8379, (3.768257100274985, 47639)),
#  (8883, (3.8640426532852437, 19131)),
#  (9954, (3.938280235693598, 10013))]

# %% [markdown]
# #### Generate predictions for new users

# %% [markdown]
# Let's generate a fake user by rating some of the available movies

# %%
movies.take(1000)
# Out:
# [['1', 'Dinosaur Planet', '2003'],
#  ['2', 'Isle of Man TT 2004 Review', '2004'],
#  ['3', 'Character', '1997'],
#  ['4', "Paula Abdul's Get Up & Dance", '1994'],
#  ['5', 'The Rise and Fall of ECW', '2004'],
#  ['6', 'Sick', '1997'],
#  ['7', '8 Man', '1992'],
#  ['8', 'What the #$*! Do We Know!?', '2004'],
#  ['9', "Class of Nuke 'Em High 2", '1991'],
#  ['10', 'Fighter', '2001'],
#  ['11', 'Full Frame: Documentary Shorts', '1999'],
#  ['12', 'My Favorite Brunette', '1947'],
#  ['13',
#   'Lord of the Rings: The Return of the King: Extended Edition: Bonus Material',
#   '2003'],
#  ['14', 'Nature: Antarctica', '1982'],
#  ['15', 'Neil Diamond: Greatest Hits Live', '1988'],
#  ['16', 'Screamers', '1996'],
#  ['17', '7 Seconds', '2005'],
#  ['18', 'Immortal Beloved', '1994'],
#  ['19', "By Dawn's Early Light", '2000'],
#  ['20', 'Seeta Aur Geeta', '1972'],
#  ['21', 'Strange Relations', '2002'],
#  ['22', 'Chump Change', '2000'],
#  ['23',
#   "Clifford: Clifford Saves the Day! / Clifford's Fluffiest Friend Cleo",
#   '2001'],
#  ['24', 'My Bloody Valentine', '1981'],
#  ['25', 'Inspector Morse 31: Death Is Now My Neighbour', '1997'],
#  ['26', 'Never Die Alone', '2004'],
#  ['27', "Sesame Street: Elmo's World: The Street We Live On", '1962'],
#  ['28', 'Lilo and Stitch', '2002'],
#  ['29', 'Boycott', '2001'],
#  ['30', "Something's Gotta Give", '2003'],
#  ['31', 'Classic Albums: Meat Loaf: Bat Out of Hell', '1999'],
#  ['32', "ABC Primetime: Mel Gibson's The Passion of the Christ", '2004'],
#  ['33', 'Aqua Teen Hunger Force: Vol. 1', '2000'],
#  ['34', "Ashtanga Yoga: Beginner's Practice with Nicki Doane", '2003'],
#  ['35', 'Ferngully 2: The Magical Rescue', '2000'],
#  ['36', 'Lady Chatterley', '1992'],
#  ['37', "Zatoichi's Conspiracy", '1973'],
#  ['38', 'Daydream Obsession', '2003'],
#  ['39', 'Love Reinvented', '2000'],
#  ['40', 'Pitcher and the Pin-Up', '2004'],
#  ['41', 'Horror Vision', '2000'],
#  ['42', 'Searching for Paradise', '2002'],
#  ['43', 'Silent Service', '2000'],
#  ['44', 'Spitfire Grill', '1996'],
#  ['45', 'The Love Letter', '1999'],
#  ['46', 'Rudolph the Red-Nosed Reindeer', '1964'],
#  ['47', 'The Bad and the Beautiful', '1952'],
#  ['48', 'Justice League', '2001'],
#  ['49', 'Devo: The Complete Truth About De-evolution', '2003'],
#  ['50', 'A Yank in the R.A.F.', '1941'],
#  ['51', 'Jonah: A VeggieTales Movie: Bonus Material', '2002'],
#  ['52', 'The Weather Underground', '2002'],
#  ['53', 'The Bonesetter', '2003'],
#  ['54', "We're Not Married", '1952'],
#  ['55', 'Jade', '1995'],
#  ['56', 'Carandiru', '2004'],
#  ['57', 'Richard III', '1995'],
#  ['58', 'Dragonheart', '1996'],
#  ['59', 'Sex and the Beauties', '2003'],
#  ['60', 'The Libertine', '1969'],
#  ['61', 'Ricky Martin: One Night Only', '1999'],
#  ['62', "Ken Burns' America: Empire of the Air", '1991'],
#  ['63', 'Crash Dive', '1943'],
#  ['64', 'Outside the Law', '2001'],
#  ['65', 'Lost in the Pershing Point Hotel', '2000'],
#  ['66', 'Barbarian Queen 2', '1989'],
#  ['67', 'Vampire Journals', '1997'],
#  ['68', 'Invader Zim', '2004'],
#  ['69', 'WWE: Armageddon 2003', '2003'],
#  ['70', 'Tai Chi: The 24 Forms', '1999'],
#  ['71', 'Maya Lin: A Strong Clear Vision', '1995'],
#  ['72', 'At Home Among Strangers', '1974'],
#  ['73', 'Davy Crockett: 50th Anniversary Double Feature', '1954'],
#  ['74', '6ixtynin9', '1999'],
#  ['75', 'Grind', '1997'],
#  ['76', 'I Love Lucy: Season 2', '1952'],
#  ['77', 'Congo', '1995'],
#  ['78', 'Jingle All the Way', '1996'],
#  ['79', 'The Killing', '1956'],
#  ['80', 'Winter Kills', '1979'],
#  ['81', 'Antarctica: IMAX', '1991'],
#  ['82', 'The Frogmen', '1951'],
#  ['83', 'Silkwood', '1983'],
#  ['84', 'The Powerpuff Girls Movie', '2002'],
#  ['85', 'Elfen Lied', '2005'],
#  ['86', 'Iron Monkey 2', '1996'],
#  ['87', 'Louder Than Bombs', '2002'],
#  ['88', 'Record of Lodoss War: Chronicles of the Heroic Knight', '1998'],
#  ['89', 'Chain of Command', '2000'],
#  ['90', 'The Lemon Drop Kid', '1951'],
#  ['91', 'WWE: Royal Rumble 2005', '2005'],
#  ['92', "ECW: Cyberslam '99", '2002'],
#  ['93', 'They Came Back', '2004'],
#  ['94', 'G3: Live in Concert', '2000'],
#  ['95', 'Dona Herlinda and Her Son', '1985'],
#  ['96', 'Inside the Space Station', '2000'],
#  ['97', 'Mostly Martha', '2002'],
#  ['98', 'The Battle of Algiers: Bonus Material', '1965'],
#  ['99', 'A Fishy Story', '1989'],
#  ['100', 'Sam the Iron Bridge', '1993'],
#  ['101', 'Complete Shamanic Princess', '1997'],
#  ['102', 'Notre Musique', '2004'],
#  ['103', 'Sanford and Son: Season 6', '1976'],
#  ['104', 'The Great Race', '1965'],
#  ['105', 'Obsessed', '2002'],
#  ['106',
#   'Stevie Ray Vaughan and Double Trouble: Live at Montreux 1982 & 1985',
#   '2004'],
#  ['107', 'Magnolia: Bonus Material', '2000'],
#  ['108', 'Spartan', '2004'],
#  ['109', 'No Way Back', '1996'],
#  ['110', 'Scandal', '1989'],
#  ['111', 'Duplex (Widescreen)', '2003'],
#  ['112', 'The Eye of Vichy', '1993'],
#  ['113', "Bruce Lee: A Warrior's Journey", '2000'],
#  ['114', 'Dominion Tank Police Part 1 & 2', '1989'],
#  ['115', 'Lord Peter Wimsey: Murder Must Advertise', '1973'],
#  ['116', 'Bear Cub', '2004'],
#  ['117', 'Silk Stockings', '1957'],
#  ['118', 'Rambo: First Blood Part II', '1985'],
#  ['119', 'Travel the World by Train: Africa', '1999'],
#  ['120', 'Plain Dirty', '2004'],
#  ['121', 'Beyonce: Live at Wembley', '2003'],
#  ['122', 'Cube 2: Hypercube', '2002'],
#  ['123', 'Chain of Fools', '2000'],
#  ['124', 'Cold Blooded', '2000'],
#  ['125', 'Nighthawks', '1981'],
#  ['126', 'Vampire Effect (aka Twins Effect)', '2003'],
#  ['127', 'Fatal Beauty', '1987'],
#  ['128', 'Mr. Vampire', '1985'],
#  ['129', 'Darkwolf', '2003'],
#  ['130', 'Drowning on Dry Land', '1999'],
#  ['131', 'Arachnid', '2002'],
#  ['132', 'Lucio Fulci: The Beyond', '1981'],
#  ['133', 'Viva La Bam: Season 1', '2003'],
#  ['134', 'Spirit Lost', '1996'],
#  ['135', 'GTO: Great Teacher Onizuka: Set 2', '1998'],
#  ['136', 'Cat and the Canary', '1927'],
#  ['137', 'Naked Lies', '1998'],
#  ['138', 'Star Trek: Voyager: Season 1', '1995'],
#  ['139', 'Allergies: A Natural Approach', '2001'],
#  ['140', 'Lost in the Wild', '1993'],
#  ['141', 'Goddess of Mercy', '2004'],
#  ['142', 'The Tricky Master', '2000'],
#  ['143', 'The Game', '1997'],
#  ['144', 'Deepak Chopra: The Way of the Wizard & Alchemy', '2000'],
#  ['145', 'Get Out Your Handkerchiefs', '1978'],
#  ['146', 'Cannibal Women in the Avocado Jungle of Death', '1988'],
#  ['147', 'Where Sleeping Dogs Lie', '1992'],
#  ['148', 'Sweet November', '2001'],
#  ['149', 'The Edward R. Murrow Collection', '2005'],
#  ['150', 'Firetrap', '2001'],
#  ['151', 'Sleepover Nightmare', '2005'],
#  ['152', 'A Little Princess', '1995'],
#  ['153', 'MTV Yoga', '2002'],
#  ['154', 'Demon Warrior Koji', '2000'],
#  ['155', 'The Strongest Man in the World', '1975'],
#  ['156', 'Husbands and Wives', '1992'],
#  ['157', 'Laird: White Knuckle Extreme', '2004'],
#  ['158', 'A Killer Within', '2004'],
#  ['159', 'Gentlemen of Fortune', '1971'],
#  ['160', 'Gormenghast', '2000'],
#  ['161', 'Ninotchka', '1939'],
#  ['162', 'John Cleese on How to Irritate People', '1968'],
#  ['163', 'MTV: Making the Band 2: Best of Season 1', '2002'],
#  ['164', 'One Last Dance', '2003'],
#  ['165', 'Richard Pryor: Live on the Sunset Strip', '1982'],
#  ['166', 'Fame', '1980'],
#  ['167', 'The Chorus', '2004'],
#  ['168', 'Smokey and the Bandit Part 3', '1983'],
#  ['169', 'Cartoon Network Halloween: 9 Creepy Cartoon Capers', '2004'],
#  ['170', 'Tomorrow', '1972'],
#  ['171', 'Funny Face', '1957'],
#  ['172', 'Jack', '2003'],
#  ['173', "The Devil's Brigade", '1968'],
#  ['174', 'Adam-12: Season 1', '1968'],
#  ['175', 'Reservoir Dogs', '1992'],
#  ['176', 'The History Channel Presents: Troy: Unearthing the Legend', '2004'],
#  ['177', 'Pressure', '2002'],
#  ['178', 'Regular Guys', '1996'],
#  ['179', 'Bollywood Bound', '2003'],
#  ['180', 'Scratch', '2002'],
#  ['181', 'The Last Shot', '2004'],
#  ['182', 'Moby: Play', '2001'],
#  ['183', 'IFilm: Deranged', '2005'],
#  ['184', 'Billy Blanks: Tae Bo: Cardio Circuit 1', '2004'],
#  ['185',
#   'Missing in Action 2: The Beginning / Missing in Action 3: Braddock',
#   '1985'],
#  ['186', 'Panic in the Streets', '1950'],
#  ['187', 'Death to Smoochy', '2002'],
#  ['188', 'Dead Birds', '2005'],
#  ['189', 'Airplane II: The Sequel', '1982'],
#  ['190', 'Blood and Sand', '1989'],
#  ['191', 'X2: X-Men United', '2003'],
#  ['192', 'The SoulTaker', '2003'],
#  ['193', 'Marilyn Manson: Fear of a Satanic Planet', '2005'],
#  ['194', 'Arliss: The Best of Arliss', '1996'],
#  ['195', 'Chasing Freedom', '2004'],
#  ['196', 'Peter Tosh: Stepping Razor: Red X', '1992'],
#  ['197', 'Taking Lives', '2004'],
#  ['198', 'Gupt', '1997'],
#  ['199', 'The Deer Hunter', '1978'],
#  ['200', 'The Fall of the Roman Empire', '1964'],
#  ['201', 'Home Movie', '2001'],
#  ['202', "Ruby's Bucket of Blood", '2001'],
#  ['203', 'Sports Illustrated Swimsuit Edition: 1997', '1997'],
#  ['204', 'Venus Boyz', '2002'],
#  ['205', 'Troy: Bonus Material', '2004'],
#  ['206', 'Unconstitutional: The War on Our Civil Liberties', '2004'],
#  ['207', 'Denise Austin: Ultimate Fat Burner', '2001'],
#  ['208', 'The Three Stooges: Sing a Song of Six Pants', '1947'],
#  ['209', 'Star Trek: Deep Space Nine: Season 5', '1996'],
#  ['210', 'Onmyoji', '2001'],
#  ['211', 'The Agronomist', '2004'],
#  ['212', 'Querelle', '1982'],
#  ['213', 'Dinner Rush', '2001'],
#  ['214', 'Read-Along: Beauty and the Beast', '2002'],
#  ['215', "That '70s Show: Season 1", '1998'],
#  ['216', 'Impostor', '2000'],
#  ['217', 'Cherry 2000', '1988'],
#  ['218', 'Triumph: Live at the US Festival', '1983'],
#  ['219', 'Neon Bible', '1995'],
#  ['220', 'Winston Churchill: The Wilderness Years', '1983'],
#  ['221', 'Voyage to the Planets and Beyond', '2005'],
#  ['222', 'Yellow', '1998'],
#  ['223', "Chappelle's Show: Season 1", '2003'],
#  ['224', 'Midsomer Murders: Blood Will Out', '1999'],
#  ['225', 'The Cookout', '2004'],
#  ['226', 'Henry: Portrait of a Serial Killer 2', '1996'],
#  ['227', 'The Carol Burnett Show: Show Stoppers', '2001'],
#  ['228', 'Butch and Sundance: The Early Days', '1979'],
#  ['229', 'Peter Gabriel: Growing Up Live', '2003'],
#  ['230', 'Unsolved Mysteries: Psychics', '1987'],
#  ['231', 'Marooned in Iraq', '2002'],
#  ['232', 'Gross Anatomy', '1989'],
#  ['233', "Chato's Land", '1971'],
#  ['234', 'Animation Legend: Winsor McCay', '1921'],
#  ['235', 'Unhook the Stars', '1996'],
#  ['236', 'Cartoon Crazys Sci-Fi', '1998'],
#  ['237', 'Broken Blossoms', '1918'],
#  ['238', 'Led Zeppelin: The Song Remains the Same', '1976'],
#  ['239', 'Winnie the Pooh: Springtime with Roo', '2004'],
#  ['240', 'Woman of the Year', '1942'],
#  ['241', 'North by Northwest', '1959'],
#  ['242', 'Neon Genesis Evangelion: The End of Evangelion', '1995'],
#  ['243', 'Pressure Point', '1962'],
#  ['244', 'Stellvia', '2004'],
#  ['245', 'Road Dogz', '2002'],
#  ['246', 'The Boston Strangler', '1968'],
#  ['247', 'Oleanna', '1994'],
#  ['248', "Michael Moore's The Awful Truth: Season 2", '2001'],
#  ['249', 'The Hunters', '1958'],
#  ['250', 'Cast a Giant Shadow', '1966'],
#  ['251', "Midsomer Murders: Strangler's Wood", '2000'],
#  ['252', 'Stuart Little 2', '2002'],
#  ['253', 'A Night at the Opera', '1935'],
#  ['254', 'Westender', '2003'],
#  ['255', 'The Hunchback of Notre Dame II', '2001'],
#  ['256', 'Ghost Dog: The Way of the Samurai', '2000'],
#  ['257', "Charlotte's Web", '1973'],
#  ['258', 'Mann', '1999'],
#  ['259', 'Animal', '2004'],
#  ['260', 'Marat / Sade', '1967'],
#  ['261', 'The Big Clock', '1948'],
#  ['262', 'Herbie Rides Again', '1974'],
#  ['263', 'Dragon Ball: Tournament Saga', '2001'],
#  ['264', 'Angelina Ballerina: Lights', '2002'],
#  ['265', 'The Jeff Corwin Experience: Costa Rica and the Amazon', '2002'],
#  ['266', 'Saudade Do Futuro', '2000'],
#  ['267', 'Touched by an Angel: Season 1', '1994'],
#  ['268', 'The Final Countdown', '1980'],
#  ['269', 'Parenthood', '1989'],
#  ['270', 'Sex and the City: Season 4', '2001'],
#  ['271', 'Saludos Amigos', '1943'],
#  ['272', 'Female Yakuza Tale', '1973'],
#  ['273', 'Taxi', '2004'],
#  ['274', 'Crazy as Hell', '2002'],
#  ['275', 'Evelyn', '2002'],
#  ['276', 'Cold Harvest', '1998'],
#  ['277', 'Enigma: MCMXC A.D', '2003'],
#  ['278', '100 Days Before the Command', '1990'],
#  ['279', 'Micki and Maude', '1984'],
#  ['280', 'Sarah Brightman: In Concert', '1998'],
#  ['281', 'The Legend', '1993'],
#  ['282', 'Blue Seed: Beyond', '2003'],
#  ['283', 'If These Walls Could Talk', '1996'],
#  ['284', 'Sasquatch Hunters', '2005'],
#  ['285', "The Devil's Own", '1997'],
#  ['286', 'Thunderbirds Are Go', '1966'],
#  ['287', 'Luther Vandross: Always and Forever: An Evening of Songs', '1994'],
#  ['288', 'Saturday Night Live: The Best of Chris Kattan', '2004'],
#  ['289', 'The Avengers', '1998'],
#  ['290', 'Harold and Kumar Go to White Castle', '2004'],
#  ['291', 'Chained Heat 3: Hell Mountain', '2000'],
#  ['292', 'Saturday Night Live: The Best of Gilda Radner', '2005'],
#  ['293', 'Lennon Legend: The Very Best of John Lennon', '2003'],
#  ['294', 'Oasis', '2002'],
#  ['295', 'Ace Ventura: When Nature Calls', '1995'],
#  ['296', 'In His Life: The John Lennon Story', '2000'],
#  ['297', 'The Hebrew Hammer', '2003'],
#  ['298', 'Crunch: Pick Your Spot Pilates', '2002'],
#  ['299', "Bridget Jones's Diary", '2001'],
#  ['300', 'Option Zero', '1997'],
#  ['301', 'Hard Ground', '2003'],
#  ['302', 'The Isle', '2001'],
#  ['303', 'Les Liaisons Dangereuses', '1959'],
#  ['304', 'King of the Hill: Season 1', '1997'],
#  ['305', 'Jack', '1996'],
#  ['306', 'Sesame Street: Sing Yourself Silly!', '2005'],
#  ['307', 'Godsmack: Smack This!', '2002'],
#  ['308', 'The Legend of the 7 Golden Vampires/7 Brothers of Dracula', '1974'],
#  ['309', 'The Day of the Locust', '1975'],
#  ['310', 'Leila', '2000'],
#  ['311', 'Ed Wood', '1994'],
#  ['312', 'High Fidelity', '2000'],
#  ['313', 'Pay It Forward', '2000'],
#  ['314', 'Saturday Night Live: The Best of Jon Lovitz', '1985'],
#  ['315', 'Combat! Season 3: Operation 2', '1964'],
#  ['316', 'Futurama: Monster Robot Maniac Fun Collection', '1999'],
#  ['317', 'Mandela and de Klerk', '1997'],
#  ['318', 'Beyond Suspicion', '1994'],
#  ['319', 'Straight to Hell', '1987'],
#  ['320', 'Eat Your Heart Out', '1997'],
#  ['321', 'Ju-Rei: The Uncanny', '2004'],
#  ['322', 'Flesh Gordon', '1974'],
#  ['323', 'Modern Vampires', '1999'],
#  ['324', "Mother's Boys", '1994'],
#  ['325', 'Ghosts of Rwanda: Frontline', '2004'],
#  ['326', 'The Plainsman', '1937'],
#  ['327', 'Storefront Hitchcock', '1997'],
#  ['328', 'Deftones: Live in Hawaii', '2002'],
#  ['329', 'Dogma', '1999'],
#  ['330', 'Wild Things', '1998'],
#  ['331', 'Chasing Amy', '1997'],
#  ['332', 'They Crawl', '2002'],
#  ['333', 'Mail Call: The Best of Season 2', '2003'],
#  ['334', 'The Pacifier', '2005'],
#  ['335', 'Fear No Evil', '1981'],
#  ['336', 'The Driver', '1978'],
#  ['337', 'Star 80', '1983'],
#  ['338', 'The Three Stooges: Three Smart Saps', '1942'],
#  ['339', 'Rolling Stones: Rock and Roll Circus', '1968'],
#  ['340', 'Midnight: 2000 Seen By...', '1998'],
#  ['341', 'Tremors 4: The Legend Begins', '2004'],
#  ['342', 'Noir', '2001'],
#  ['343', 'French and Saunders: Live', '2000'],
#  ['344', 'The Taming of the Shrew', '1967'],
#  ['345', 'Star Trek: Voyager: Season 5', '1998'],
#  ['346', 'Up and Down', '2005'],
#  ['347', 'Iceman Cometh', '1989'],
#  ['348', 'The Last Temptation of Christ', '1988'],
#  ['349', 'The Swarm', '1978'],
#  ['350', 'Dr. Quinn', '1993'],
#  ['351', 'Guns of the Magnificent Seven', '1969'],
#  ['352', 'Pick a Card', '1997'],
#  ['353', 'Life or Something Like It', '2002'],
#  ['354', 'Sadomania', '1981'],
#  ['355', 'Sinful Nuns of St. Valentine', '1973'],
#  ['356', 'Look at Me', '2005'],
#  ['357', 'House of Sand and Fog', '2003'],
#  ['358', 'The Onion Field', '1979'],
#  ['359', 'Absolutely Fabulous: Series 5', '2003'],
#  ['360', 'Lies', '1999'],
#  ['361', 'The Phantom of the Opera: Special Edition', '2004'],
#  ['362', 'The Flintstones in Viva Rock Vegas', '2000'],
#  ['363', 'Stark Raving Mad', '2002'],
#  ['364', 'Billy Blanks: Tae Bo: Contact 2', '2004'],
#  ['365', 'R.E.M.: Tourfilm', '1989'],
#  ['366', 'Still', '2004'],
#  ['367', 'Spun', '2003'],
#  ['368', 'The Best of Designing Women', '1986'],
#  ['369', 'Playing Mona Lisa', '2000'],
#  ['370', 'Chaplin', '1918'],
#  ['371', 'The Trouble with Angels', '1966'],
#  ['372', 'Jeans', '1998'],
#  ['373', 'Third World Cop', '2000'],
#  ['374', 'The Little Girl Who Lives Down the Lane', '1976'],
#  ['375', 'Nine Dead Gay Guys', '2003'],
#  ['376', 'Genesis: The Way We Walk: Live in Concert', '2001'],
#  ['377', 'Dick Francis: The Racing Game', '1979'],
#  ['378', 'Party Monster', '2003'],
#  ['379', 'Crash Dive', '1996'],
#  ['380', 'Live Wire', '1992'],
#  ['381', 'Out for Justice', '1991'],
#  ['382', 'Buried in the Sand: The Deception of America', '2004'],
#  ['383', 'Hit Team', '2001'],
#  ['384', 'Crossroads', '1986'],
#  ['385', 'The Santa Clause 2', '2002'],
#  ['386', 'Princess Caraboo', '1994'],
#  ['387', "Bizet's Carmen", '1984'],
#  ['388', 'Body Chemistry', '1990'],
#  ['389', 'Steal', '2002'],
#  ['390', 'The Fan', '1981'],
#  ['391', 'The Monkees: Season 2', '1967'],
#  ['392', "Danielle Steel's Heartbeat", '1993'],
#  ['393', 'The Replacement Killers', '1998'],
#  ['394', '20', '1916'],
#  ['395', 'Captain Blood', '1935'],
#  ['396', 'Arjuna: Complete Collection', '2001'],
#  ['397', 'A Night in Casablanca', '1946'],
#  ['398', 'In the Realm of the Senses', '1976'],
#  ['399', 'Fangs', '2001'],
#  ['400', 'Rio Lobo', '1970'],
#  ['401', 'Halloween 5: The Revenge of Michael Myers', '1989'],
#  ['402', 'Pan Tadeusz', '1999'],
#  ['403', 'Substitute 4: Failure is Not an Option', '2000'],
#  ['404', 'The Shaft', '2001'],
#  ['405', 'Wings of Desire', '1987'],
#  ['406', 'Hostage', '2005'],
#  ['407', 'The Abductors', '1972'],
#  ['408', 'Nightbreed', '1990'],
#  ['409', 'Godzilla vs. The Sea Monster', '1966'],
#  ['410', 'Frank Lloyd Wright', '1998'],
#  ['411', 'Vendetta', '1999'],
#  ['412', 'Jay Jay the Jet Plane: Adventures in Learning', '1999'],
#  ['413', 'Igby Goes Down', '2002'],
#  ['414', 'Girl', '1999'],
#  ['415', 'Reign in Darkness', '2002'],
#  ['416', 'Elephant', '2003'],
#  ['417', 'Transformers: Season 3: Part 1', '1986'],
#  ['418', 'The Deal', '2004'],
#  ['419', 'George Lopez: Why You Crying?', '2005'],
#  ['420', 'Saturday Night Live: The Best of Dana Carvey', '1999'],
#  ['421', "Agatha Christie's Poirot: Sad Cypress", '2003'],
#  ['422', 'The Unsinkable Molly Brown', '1964'],
#  ['423', 'My Favorite Martian #1', '1963'],
#  ['424', 'Happiness', '1998'],
#  ['425', 'The 10th Kingdom', '2000'],
#  ['426', "Recess: School's Out", '2001'],
#  ['427', 'Graveyard Shift', '1990'],
#  ['428', "Barney: Barney's Colorful World: Live", '2004'],
#  ['429', 'Zeus and Roxanne', '1997'],
#  ['430', 'Chobits', '2002'],
#  ['431', 'Millennium Actress', '2002'],
#  ['432', 'Les Miserables in Concert', '1996'],
#  ['433', 'Untamed Heart', '1993'],
#  ['434', "Extreme Engineering: Tokyo's Sky City", '2004'],
#  ['435', 'Love Can Seriously Damage Your Health', '1996'],
#  ['436', 'Girls Just Want to Have Fun', '1985'],
#  ['437', 'Beyblade: Fierce Battle', '2005'],
#  ['438', 'Bean: The Movie', '1997'],
#  ['439', 'Town Without Pity', '1961'],
#  ['440', 'Just 4 Kicks', '2003'],
#  ['441', 'Dark Shadows: Vol. 9', '1968'],
#  ['442', 'Mississippi Burning', '1988'],
#  ['443', 'Rabbit-Proof Fence', '2002'],
#  ['444', 'The Inner Tour', '2001'],
#  ['445', 'Michael Collins', '1996'],
#  ['446', 'The Underneath', '1995'],
#  ['447', 'The Making of Fanny and Alexander', '1986'],
#  ['448', 'Oswald: Welcome to the Big City!', '2001'],
#  ['449', 'Jimmy Buffett: MiniMatinee #1', '2003'],
#  ['450', "Isaac Stern: Life's Virtuoso", '2000'],
#  ['451', 'Batman the Animated Series: Vol. 3', '1993'],
#  ['452', 'Scorched', '2002'],
#  ['453', 'Simple Men', '1992'],
#  ['454', 'Xena: Warrior Princess: Season 3', '1995'],
#  ['455', 'Cardcaptor Sakura: The Movie', '1999'],
#  ['456', 'Emma (Miniseries)', '1996'],
#  ['457', 'Kill Bill: Vol. 2', '2004'],
#  ['458', 'Blast', '2001'],
#  ['459', 'Basquiat', '1996'],
#  ['460', 'Pink Narcissus', '1971'],
#  ['461', 'Nightwalker #1: Midnight Detective', '2000'],
#  ['462', 'Classic Cartoon Favorites: Starring Donald', '2005'],
#  ['463', 'The Twilight Zone: Vol. 12', '1962'],
#  ['464', 'The Return of Ruben Blades', '1987'],
#  ['465', 'Coolie No.1', '1995'],
#  ['466', 'Doogie Howser', '1990'],
#  ['467', 'Topper Returns', '1941'],
#  ['468', 'The Matrix: Revolutions', '2003'],
#  ['469', 'First Night of My Life: 2000 Seen By...', '1998'],
#  ['470', 'Beneath Loch Ness', '2001'],
#  ['471', 'City Lights', '1931'],
#  ['472', 'Mr. Jealousy', '1998'],
#  ['473', 'Princess Mononoke', '1997'],
#  ['474', 'Legend of 1900', '1998'],
#  ['475', 'Surf Ninjas', '1993'],
#  ['476', "VeggieTales Classics: Where's God When I'm Scared?", '2004'],
#  ['477', 'George Carlin: Personal Favorites', '1990'],
#  ['478', 'The Beverly Hillbillies', '1962'],
#  ['479', 'George Carlin: What Am I Doing in New Jersey?', '1988'],
#  ['480', 'Flypaper', '1997'],
#  ['481', 'Building the Great Pyramid', '2002'],
#  ['482', 'Frida', '2002'],
#  ['483', 'Rush Hour 2', '2001'],
#  ['484', "Danielle Steel's Jewels", '1992'],
#  ['485', "The Avengers '67", '1967'],
#  ['486', 'Journey to the Center of the Earth', '1959'],
#  ['487', 'Doctor Who: Lost in Time: The Patrick Troughton Years', '1968'],
#  ['488', 'His Secret Life', '2001'],
#  ['489', 'Return to Paradise', '1998'],
#  ['490', 'The Passion of Ayn Rand', '1999'],
#  ['491', 'Torn Curtain', '1966'],
#  ['492', 'Mrs. Soffel', '1984'],
#  ['493', 'The Giallo Collection: Who Saw Her Die?', '1972'],
#  ['494', "Monty Python's The Meaning of Life: Special Edition", '1983'],
#  ['495', 'Mission Kashmir', '2000'],
#  ['496', 'Primus: Hallucino-Genetics Live 2004', '2004'],
#  ['497', "Broadway's Lost Treasures", '2003'],
#  ['498', 'Glory: Bonus Material', '1989'],
#  ['499', 'Under Suspicion', '2000'],
#  ['500', 'Mail Call: The Best of Season 1', '2002'],
#  ['501', 'Three Days of the Condor', '1975'],
#  ['502', 'Mitch Hedberg: Mitch All Together', '2003'],
#  ['503', 'Max and Ruby: Springtime for Max and Ruby', '2005'],
#  ['504', 'The Twilight Zone: Vol. 27', '1964'],
#  ['505', 'A Thousand Acres', '1997'],
#  ['506', "Blank Generation / Dancin' Barefoot", '1976'],
#  ['507', 'Nevada Smith', '1966'],
#  ['508', 'Saint Jack', '1979'],
#  ['509', 'The Volcano Disaster', '2004'],
#  ['510', "Blue's Clues: Blue's Room: It's Hug Day", '2004'],
#  ['511', 'Avenging Angelo', '2002'],
#  ['512', 'Bubblegum Crisis: Hurricane Live!', '2000'],
#  ['513', 'Butterfly Kiss', '1995'],
#  ['514', 'Santana: Supernatural Live', '2000'],
#  ['515', 'Avia Vampire Hunter', '2005'],
#  ['516', 'Monsoon Wedding', '2001'],
#  ['517', 'Two Can Play That Game', '2001'],
#  ['518', 'The Prime of Miss Jean Brodie', '1969'],
#  ['519', 'From Mao to Mozart: Isaac Stern in China', '1979'],
#  ['520', "E's Otherwise", '2004'],
#  ['521', 'Presenting Felix the Cat', '1927'],
#  ['522', 'Love Songs', '1999'],
#  ['523', 'My Side of the Mountain', '1969'],
#  ['524', 'Mumford', '1999'],
#  ['525', 'The Last Seduction II', '1999'],
#  ['526', 'Angie', '1994'],
#  ['527', 'Barbarian Queen', '1985'],
#  ['528', "The Hitchhiker's Guide to the Galaxy", '2005'],
#  ['529', 'Summer of the Monkeys', '1998'],
#  ['530', 'Return to Horror High', '1987'],
#  ['531', "You're Invited to Mary-Kate and Ashley's Vacation Parties", '1996'],
#  ['532', 'Young Einstein', '1988'],
#  ['533', 'Drop Dead Fred', '1991'],
#  ['534', 'With a Friend Like Harry', '2000'],
#  ['535', 'The Alamo', '1960'],
#  ['536', 'Sol Goode', '2001'],
#  ['537', 'Here is Greenwood', '1991'],
#  ['538', 'A Crime of Passion', '2003'],
#  ['539', 'Rumpole of the Bailey: Series 4', '1987'],
#  ['540', 'Ghosts of the Abyss: Bonus Material', '2003'],
#  ['541', 'King Cobra', '1998'],
#  ['542', 'The Blackout', '1997'],
#  ['543',
#   'Roughnecks: The Starship Troopers Chronicles: The Pluto Campaign',
#   '1999'],
#  ['544', 'Maurice: Bonus Material', '1987'],
#  ['545', 'Bob the Builder: The Big Game', '2002'],
#  ['546', 'The Strip Game', '2005'],
#  ['547', 'Kuffs', '1992'],
#  ['548', 'Hudson Hawk', '1991'],
#  ['549', 'Rage at Dawn', '1955'],
#  ['550', 'First Knight', '1995'],
#  ['551', 'The Santa Clause', '1994'],
#  ['552', 'Radioland Murders', '1994'],
#  ['553', 'Rangeela', '1995'],
#  ['554', 'Solaris', '1972'],
#  ['555', 'Cadfael: A Morbid Taste for Bones', '1996'],
#  ['556', 'New Waterford Girl', '1999'],
#  ['557', 'Liebestraum', '1991'],
#  ['558', 'Fantastic Four', '1994'],
#  ['559', 'Rebecca: Bonus Material', '1940'],
#  ['560', 'Star Trek: Enterprise: Season 3', '2003'],
#  ['561', 'High and Low', '1963'],
#  ['562', 'Bloody Mallory', '2002'],
#  ['563', 'Jimmy Neutron: Boy Genius', '2001'],
#  ['564', 'Predator 2', '1990'],
#  ['565',
#   'Tom Petty and the Heartbreakers: Live at the Olympic: The Last DJ',
#   '2002'],
#  ['566', 'Bullet', '1996'],
#  ['567', 'Dunsmore', '2003'],
#  ['568', 'Knights of Ramune', '1999'],
#  ['569', 'The In-Laws', '1979'],
#  ['570', 'The Visit', '2000'],
#  ['571', 'American Beauty', '1999'],
#  ['572', 'The Masque of the Red Death / The Premature Burial', '1962'],
#  ['573', 'Winners & Sinners', '1983'],
#  ['574', 'Strangers When We Meet', '1960'],
#  ['575', 'Highlander: Season 4', '1994'],
#  ['576', 'Popular: Season 2', '2000'],
#  ['577', 'The Twilight Zone: Vol. 36', '1961'],
#  ['578', 'The Terror', '1963'],
#  ['579', 'The Autobiography of Miss Jane Pittman', '1973'],
#  ['580', 'THX 1138: Special Edition', '1971'],
#  ['581', 'Black Jack: The Movie', '1993'],
#  ['582', 'Jo Jo Dancer', '1986'],
#  ['583', 'Third Man on the Mountain', '1959'],
#  ['584', 'The Curve', '1998'],
#  ['585', 'My Family', '1995'],
#  ['586', 'Shanghai Triad', '1995'],
#  ['587', 'The Scarlet and the Black', '1983'],
#  ['588', 'Blue Planet: IMAX', '1990'],
#  ['589', 'Northanger Abbey', '2000'],
#  ['590', 'Michael McDonald: A Gathering of Friends', '2001'],
#  ['591', 'Particles of Truth', '2003'],
#  ['592', 'House of Whipcord', '1974'],
#  ['593', 'Baby Genius: Mozart and Friends', '2000'],
#  ['594', 'By Hook or By Crook', '2002'],
#  ['595', 'Monarch of the Glen: Series 2', '2001'],
#  ['596', 'Alice in Wonderland (TV Version)', '1999'],
#  ['597', 'The Brady Bunch Variety Hour', '1977'],
#  ['598', 'Bobby Darin: Mack is Back', '1973'],
#  ['599', 'Sea of Love', '1989'],
#  ['600', "What's Up", '1966'],
#  ['601', 'The Smiths: The Complete Picture', '1992'],
#  ['602', 'Tokyo Raiders', '2000'],
#  ['603', 'Burn Up Excess: Vol. 1: To Serve and Protect', '1997'],
#  ['604', "Walt Disney's Timeless Tales: Vol. 2", '2005'],
#  ['605', 'The Secrets of the Dead Sea Scrolls', '2000'],
#  ['606', 'Quatermass and the Pit', '1968'],
#  ['607', 'Speed', '1994'],
#  ['608', 'The Lickerish Quartet', '1970'],
#  ['609', 'Jimmy Neutron: Attack of the Twonkies', '2002'],
#  ['610', 'Offspring: Americana', '1999'],
#  ['611', 'Spooks & Creeps', '2004'],
#  ['612', 'Cloak and Dagger', '1946'],
#  ['613', 'The Dr. Who Collection', '1965'],
#  ['614', 'Bad Boy Bubby', '1993'],
#  ['615', 'An Ideal Husband', '1999'],
#  ['616', 'SCTV Network 90: Vol. 4', '1983'],
#  ['617', 'UFC: Ultimate Fighting Championship: Ultimate Knockouts 3', '2004'],
#  ['618', 'Totally F***ed Up', '1994'],
#  ['619', 'Doctor Who: The Leisure Hive', '1980'],
#  ['620', 'Hot Wheels: World Race', '2003'],
#  ['621', 'Armageddon', '1997'],
#  ['622', "Talkin' Dirty After Dark", '1991'],
#  ['623', 'Dario Argento Collection: Vol. 2: Demons 2', '1986'],
#  ['624', 'My Mother Likes Women', '2004'],
#  ['625', 'Underground Comedy Movie', '1999'],
#  ['626', 'They Died with Their Boots On', '1941'],
#  ['627', 'Beware of a Holy Whore', '1971'],
#  ['628', 'Rescue Heroes: The Movie', '2003'],
#  ['629', 'Firestarter', '1984'],
#  ['630', 'Empire of the Ants', '1977'],
#  ['631', 'Unleashed', '2005'],
#  ['632', "Shaft's Big Score!", '1972'],
#  ['633', 'Baazigar', '1993'],
#  ['634', 'Christmas with The Simpsons', '1989'],
#  ['635', 'The Fassbinder Collection: Pioneer in Ingolstadt', '1971'],
#  ['636', 'Stir Crazy', '1980'],
#  ['637', 'National Geographic: Inside American Power: Air Force One', '2001'],
#  ['638', 'The Last Dragon', '1985'],
#  ['639', 'Jim Brown: All-American', '2002'],
#  ['640', 'To Catch a Killer', '1992'],
#  ['641', 'Charly', '1968'],
#  ['642', 'Mystery Science Theater 3000: The Hellcats', '1990'],
#  ['643', 'Buying the Cow', '2002'],
#  ['644', 'Cheyenne Warrior', '1994'],
#  ['645', 'Dear Frankie', '2004'],
#  ['646', 'Matewan', '1987'],
#  ['647', 'Cinderfella', '1960'],
#  ['648',
#   'John Mayall & The Bluesbreakers and Friends: 70th Birthday Concert',
#   '2003'],
#  ['649', 'Ricky Martin: The Ricky Martin Video Collection', '1999'],
#  ['650', "Elvira's Haunted Hills", '2002'],
#  ['651', 'The Rainbow Fish / Dazzle the Dinosaur', '1997'],
#  ['652', "Marvin's Room", '1996'],
#  ['653', 'American Tragedy', '2000'],
#  ['654', 'Return of the Chinese Boxer', '1975'],
#  ['655', 'Green Acres: Season 1', '1965'],
#  ['656', 'Veronica 2030', '2004'],
#  ['657', 'Highlander: Season 5', '1996'],
#  ['658', 'Robin Hood: Prince of Thieves', '1991'],
#  ['659', 'The Last House on the Left', '1972'],
#  ['660', 'Saving Grace', '2000'],
#  ['661', 'Who is Cletis Tout?', '2002'],
#  ['662', 'Rob Roy', '1995'],
#  ['663', 'La Femme Nikita: Season 3', '1999'],
#  ['664', 'Office Killer', '1997'],
#  ['665', 'Lipstick', '1976'],
#  ['666', 'The Man Who Came to Dinner', '2000'],
#  ['667', "Gilligan's Island: Season 2", '1965'],
#  ['668', 'Saturday Night Live: The Best of Will Ferrell 2', '2004'],
#  ['669', 'Real Kung Fu of Shaolin', '1986'],
#  ['670', 'He Loves Me', '2002'],
#  ['671', 'The Winter People', '1989'],
#  ['672', 'He Said', '1991'],
#  ['673', 'Fight Club: Bonus Material', '1999'],
#  ['674', 'Hellbound: Hellraiser II', '1988'],
#  ['675', "Rugrats All Grown Up: O' Brother!", '2004'],
#  ['676', 'Mafia!', '1998'],
#  ['677', 'In the Mood for Love', '2001'],
#  ['678', 'Loves of a Blonde', '1965'],
#  ['679', 'R.E.M.: Pop Screen', '1990'],
#  ['680', 'Better Than Sex', '2000'],
#  ['681', 'Police Academy 3: Back in Training', '1986'],
#  ['682', 'The Mighty', '1998'],
#  ['683', 'Cavalry Charge', '1951'],
#  ['684', 'Visitors of the Night', '1995'],
#  ['685', 'Running Out of Time', '1999'],
#  ['686', 'Bedazzled', '2000'],
#  ['687',
#   'Peter Jennings Reports: The Kennedy Assassination: Beyond Conspiracy',
#   '2003'],
#  ['688', 'The History Channel Presents: The Alamo', '2003'],
#  ['689', 'One True Thing', '1998'],
#  ['690', 'Baby Einstein: Baby Da Vinci', '2004'],
#  ['691', "Angel's Dance", '1999'],
#  ['692', 'The Hand that Rocks the Cradle', '1992'],
#  ['693', 'The Quest', '1996'],
#  ['694', 'When Dinosaurs Roamed America', '2000'],
#  ['695', 'Koma', '2004'],
#  ['696', 'Last Man Standing', '1996'],
#  ['697', "Caillou: Caillou's Treasure Hunt and Other Adventures", '2000'],
#  ['698', 'Daud', '1997'],
#  ['699', 'Mahoromatic: Automatic Maiden: Summer Special', '2004'],
#  ['700', "Todd McFarlane's Spawn", '1997'],
#  ['701', 'Nine Lives', '2002'],
#  ['702', 'For the Moment', '1996'],
#  ['703', 'Japan: Memoirs of a Secret Empire', '2004'],
#  ['704', 'A Change of Heart', '1998'],
#  ['705', 'Major League', '1989'],
#  ['706', 'Mobsters', '1991'],
#  ['707', 'The Return', '2003'],
#  ['708', 'The Perfect Storm', '2000'],
#  ['709', "Africans in America: America's Journey Through Slavery", '1998'],
#  ['710', 'Inspector Morse 9: The Last Enemy', '1993'],
#  ['711', 'Dolores Claiborne', '1994'],
#  ['712', 'Homicide: Life on the Street: Season 7', '1998'],
#  ['713', 'Cause Celebre', '1987'],
#  ['714', 'Whisper Kill', '1988'],
#  ['715', 'Film Noir Collection: D.O.A.', '1950'],
#  ['716', 'The Bravados', '1958'],
#  ['717', 'Testosterone', '2004'],
#  ['718', '44 Minutes', '2003'],
#  ['719', 'City of Industry', '1997'],
#  ['720', 'Roger & Me', '1989'],
#  ['721', 'Royal Deceit', '1994'],
#  ['722', 'The Wire: Season 1', '2003'],
#  ['723', 'Curly Sue', '1991'],
#  ['724', 'Yu Yu Hakusho', '1992'],
#  ['725', 'Woman Thou Art Loosed', '2004'],
#  ['726', 'The Haunting of Morella', '1990'],
#  ['727', 'Carlton-Browne of the F.O.', '1959'],
#  ['728', "Abigail's Party", '1977'],
#  ['729', 'Fast Food', '2000'],
#  ['730', 'Bagdad Cafe', '1988'],
#  ['731', 'Mr. Magoo', '1997'],
#  ['732', '11:14', '2005'],
#  ['733', 'Dead Ringers', '1988'],
#  ['734', 'Indochine', '1992'],
#  ['735', 'Hillary & Tenzing: Climbing to the Roof of World', '2003'],
#  ['736', 'The Last Man', '2002'],
#  ['737', 'Great Pas de Deux', '2004'],
#  ['738', 'A Slipping Down Life', '1999'],
#  ['739', 'Treading Water', '2001'],
#  ['740', 'The House on Carroll Street', '1988'],
#  ['741', "Ken Burns' America: The Congress", '1988'],
#  ['742', 'Sherlock: Case of Evil', '2002'],
#  ['743', "Widows' Peak", '1994'],
#  ['744', 'Hot War', '1998'],
#  ['745', 'Fantasy Mission Force', '1979'],
#  ['746', 'Domestic Disturbance', '2001'],
#  ['747', 'Saber Marionette J', '1996'],
#  ['748', 'I Can Do Bad All By Myself', '2002'],
#  ['749', 'Ernest Goes to Jail', '1990'],
#  ['750', 'The Librarian: Quest for the Spear', '2004'],
#  ['751', 'Halloween: H2O', '1998'],
#  ['752', 'Star Trek: The Next Generation: Season 7', '1993'],
#  ['753', 'Mary Poppins: Bonus Material', '1964'],
#  ['754', 'The Lonely Guy', '1984'],
#  ['755', 'Music Box', '1989'],
#  ['756', 'The Best of MusikLaden: Classic Rock', '2000'],
#  ['757', 'Sherlock Hound', '1984'],
#  ['758', 'Mean Girls', '2004'],
#  ['759', 'Fifteen Minutes', '2001'],
#  ['760', "Pooh's Heffalump Movie", '2005'],
#  ['761', 'O Fantasma', '2000'],
#  ['762', 'End of the Century: The Story of the Ramones', '2004'],
#  ['763', 'The Poseidon Adventure', '1972'],
#  ['764', 'Scarface: 20th Anniversary Edition: Bonus Material', '1983'],
#  ['765', 'Grief', '1994'],
#  ['766', 'A Hole in the Head', '1959'],
#  ['767', 'Edges of the Lord', '2001'],
#  ['768', 'The Star Maker', '1995'],
#  ['769', 'The Crawling Eye', '1958'],
#  ['770', 'A Perfect Candidate', '1996'],
#  ['771', 'Man in the Iron Mask', '1999'],
#  ['772', "Gloria Estefan: Don't Stop!", '1998'],
#  ['773', 'He Died with a Felafel in His Hand', '2001'],
#  ['774', "Foyle's War: Set 2", '2003'],
#  ['775', 'Man Ray: Prophet of the Avant Garde', '1999'],
#  ['776', "Dr. Seuss's The 5", '1953'],
#  ['777', 'Sherlock Holmes and the Spider Woman', '1944'],
#  ['778', 'A Touch of Frost: Seasons 7 & 8', '2003'],
#  ['779', 'Loving Jezebel', '2000'],
#  ['780', 'Churchill', '2003'],
#  ['781', 'Care Bears: Journey to Joke-a-Lot', '2004'],
#  ['782', 'Soldier of Fortune', '1998'],
#  ['783', 'For Love or Country', '2001'],
#  ['784', 'The Outer Limits: The New Series: Aliens Among Us', '1995'],
#  ['785', 'American Pop', '1981'],
#  ['786', 'Tokyo Drifter', '1966'],
#  ['787', 'La Vallee', '1972'],
#  ['788', 'Clerks', '1994'],
#  ['789', 'Boyz N the Hood', '1991'],
#  ['790', 'A Single Girl', '2000'],
#  ['791', 'Don Henley: Live Inside Job', '2000'],
#  ['792', 'Unsolved History: Salem Witch Trials', '2004'],
#  ['793', 'By Brakhage: An Anthology', '2004'],
#  ['794', 'A Stranger Among Us', '1992'],
#  ['795', 'Landmarks of Early Film', '1997'],
#  ['796', 'Rabid', '1976'],
#  ['797', 'Look Back in Anger', '1959'],
#  ['798', 'Jaws', '1975'],
#  ['799', 'Teen Titans: Season 1', '2003'],
#  ['800', 'Dracula Vs. Frankenstein', '1971'],
#  ['801', 'We Know Where You Live. Live!', '2001'],
#  ['802', 'Spies', '1928'],
#  ['803', 'Soul Assassin', '2001'],
#  ['804', 'Sherlock Holmes: The Scarlet Claw', '1944'],
#  ['805', 'Dark Shadows: Vol. 11', '1968'],
#  ['806', 'Eyes Without a Face', '1960'],
#  ['807', 'The Mouse That Roared', '1959'],
#  ['808', 'Dead Man on Campus', '1998'],
#  ['809', 'Left Behind II: Tribulation Force', '2002'],
#  ['810', 'The Matchmaker', '1958'],
#  ['811', 'The Lawnmower Man', '1992'],
#  ['812', 'The Saddle Club: Horse Crazy', '2001'],
#  ['813', 'On Cukor', '2000'],
#  ['814', 'Ruin Explorers', '2000'],
#  ['815', 'Tiger Bay', '1959'],
#  ['816', 'Marlene Dietrich: Her Own Song', '2001'],
#  ['817', 'My Bodyguard', '1980'],
#  ['818', "Logan's Run", '1976'],
#  ['819', 'The Faculty', '1998'],
#  ['820', 'Predator Island', '2005'],
#  ['821', 'Slaughter', '1972'],
#  ['822', 'Star Trek: Enterprise: Season 1', '2001'],
#  ['823', 'Sleepaway Camp II: Unhappy Campers', '1988'],
#  ['824', 'A Piece of the Action', '1977'],
#  ['825', 'Bill Cosby: Himself', '1983'],
#  ['826', 'Goosebumps: Cry of the Cat', '1998'],
#  ['827', "C'est La Vie", '1994'],
#  ['828', 'Atlantis', '1991'],
#  ['829', 'Serial Mom', '1995'],
#  ['830', 'Return to a Better Tomorrow', '1994'],
#  ['831', 'Mannequin', '1987'],
#  ['832', 'Tupac: Resurrection', '2003'],
#  ['833', 'White Squall', '1996'],
#  ['834', 'Niagara: Miracles', '1999'],
#  ['835', 'Cirque du Soleil: A Baroque Odyssey', '1994'],
#  ['836', 'Incident at Oglala: The Leonard Peltier Story', '1991'],
#  ['837', 'All in the Family: Season 3', '1972'],
#  ['838', 'Gang of Roses', '2003'],
#  ['839', 'The Thin Man Goes Home', '1945'],
#  ['840', 'The Lady Eve', '1941'],
#  ['841', 'There Goes My Baby', '1994'],
#  ['842', 'Reap the Wild Wind', '1942'],
#  ['843', 'Mansfield Park', '1999'],
#  ['844', 'La Cienaga', '2001'],
#  ['845', 'If We Had No Moon', '2004'],
#  ['846', 'Enduring Love', '2004'],
#  ['847', 'Shania Twain: The Platinum Collection', '2001'],
#  ['848', 'La Separation', '1994'],
#  ['849', 'Mr. & Mrs. Bridge', '1990'],
#  ['850', 'Stoked: The Rise and Fall of Gator', '2002'],
#  ['851', 'Back to the Future Part III', '1990'],
#  ['852', 'Disorganized Crime', '1989'],
#  ['853', 'Dragonball: The Magic Begins', '1993'],
#  ['854', "Wes Craven's Invitation to Hell", '1984'],
#  ['855', 'Bruiser', '2001'],
#  ['856', 'Devil in the Flesh 2', '2000'],
#  ['857', 'The Three Stooges Go Around the World in a Daze', '1963'],
#  ['858', 'Sports Illustrated Swimsuit Edition: 2002', '2002'],
#  ['859', 'Creepshow', '1982'],
#  ['860', 'Crime Partners', '2001'],
#  ['861', 'Rush: Rush in Rio', '2003'],
#  ['862', 'Tuck Everlasting', '2002'],
#  ['863', 'King of New York: Special Edition (Full-screen)', '1990'],
#  ['864', 'Laughing Out Loud: Vol. 1', '2001'],
#  ['865', 'Elvis by the Presleys', '2005'],
#  ['866', 'Starsky & Hutch: Season 1', '1975'],
#  ['867', 'My Dream Girl', '2003'],
#  ['868', 'La Promesse', '1996'],
#  ['869', 'Without Limits: NASA Test Projects', '1998'],
#  ['870', 'H.G. Wells and the War of the Worlds: A Documentary', '2005'],
#  ['871', 'The Jewel in the Crown', '1984'],
#  ['872', 'Seven Samurai', '1954'],
#  ['873', 'Boys Life 4: Four Play', '2003'],
#  ['874', 'Elvis Costello & the Imposters: Live in Memphis', '2004'],
#  ['875', 'Zakhm', '1998'],
#  ['876', 'Super Gals', '2001'],
#  ['877', 'A Love Divided', '1999'],
#  ['878', 'Short: International Release #2', '2000'],
#  ['879', 'Mikey and Nicky', '1976'],
#  ['880', "Sharpe 4: Sharpe's Enemy", '1994'],
#  ['881', 'Mating Habits of the Earthbound Human', '1999'],
#  ['882', 'Gloria Estefan: Evolution Tour: Live in Miami', '1996'],
#  ['883', 'Deep Cover', '1992'],
#  ['884', 'Cup Final', '1991'],
#  ['885', 'The Maldonado Miracle', '2003'],
#  ['886', 'Ray', '2004'],
#  ['887', 'Monster-in-Law: Bonus Material', '2005'],
#  ['888', 'Discovering Australia', '2001'],
#  ['889', 'Reno 911: Season 2', '2004'],
#  ['890', 'Harsh Realm: The Complete Series', '1999'],
#  ['891', "Zakk Wylde's Black Label Society: Boozed", '2003'],
#  ['892', 'The Bedford Incident', '1965'],
#  ['893', "Blue's Clues: Classic Clues", '2003'],
#  ['894', 'The Muse', '1999'],
#  ['895', 'Dersu Uzala', '1975'],
#  ['896', 'Dangerous Minds', '1995'],
#  ['897', 'Bride and Prejudice', '2004'],
#  ['898', 'The Body', '2000'],
#  ['899', 'Out of Ireland: The Hit Songs and Artists of Irish Music', '2003'],
#  ['900', 'Eat Drink Man Woman', '1994'],
#  ['901', 'Diary of a Country Priest', '1950'],
#  ['902', 'Fascination', '2004'],
#  ['903', 'Hamlet', '2000'],
#  ['904', 'Gargoyles', '2004'],
#  ['905', 'Remedy', '2005'],
#  ['906',
#   'Benny Hill: Complete and Unadulterated: The Naughty Early Years: Set 1',
#   '1969'],
#  ['907', 'Animal Crackers', '1930'],
#  ['908', 'Sense and Sensibility', '1981'],
#  ['909', 'Too Young to Die', '1990'],
#  ['910', 'Santa Fe Trail', '1940'],
#  ['911', 'Buck Rogers', '1939'],
#  ['912', 'Angelina Ballerina: Friends Forever', '2002'],
#  ['913', 'Dead Kennedys: In God We Trust', '1979'],
#  ['914', 'R.E.M.: Road Movie', '1996'],
#  ['915', 'Haven', '2001'],
#  ['916', 'Earth 2: The Complete Series', '1994'],
#  ['917', 'String Cheese Incident: Live at the Fillmore', '2003'],
#  ['918', "A Hard Day's Night: Collector's Series", '1964'],
#  ['919', 'Comedian', '2002'],
#  ['920',
#   "Satanis: The Devil's Mass / Sinthia: The Devil's Doll: Double Feature",
#   '1968'],
#  ['921', "Don't Bother to Knock", '1952'],
#  ['922', 'Gojoe: Spirit War Chronicle', '2004'],
#  ['923', 'Giant Robo', '2004'],
#  ['924', 'Taxi Zum Klo', '1981'],
#  ['925', 'Dodsworth', '1936'],
#  ['926', 'Fear Of A Punk Planet', '2002'],
#  ['927', "Danielle Steel's Changes", '1991'],
#  ['928', 'The Night That Never Happened', '1997'],
#  ['929', 'Journeys with George', '2002'],
#  ['930', 'Back to the Beach', '1987'],
#  ['931', 'Another Day in Paradise', '1998'],
#  ['932', 'Where Are We?', '1992'],
#  ['933', "Backyardigans: It's Great to Be a Ghost", '2005'],
#  ['934', 'River of No Return', '1954'],
#  ['935', 'Read Or Die', '2003'],
#  ['936', 'A Dangerous Man: Lawrence After Arabia', '1990'],
#  ['937', 'Fallen', '1998'],
#  ['938', 'Scarecrow', '2002'],
#  ['939', 'Midsomer Murders: A Tale of Two Hamlets', '2003'],
#  ['940', 'Hercules', '1997'],
#  ['941', 'Screw Loose', '1998'],
#  ['942', 'The Pagemaster', '1994'],
#  ['943', "Dave Chappelle: For What It's Worth", '2004'],
#  ['944', 'Brother', '1975'],
#  ['945', 'The Duel at Silver Creek', '1952'],
#  ['946', 'Sex and the Teenage Mind', '2002'],
#  ['947', 'The Cincinnati Kid', '1965'],
#  ['948', 'Aap Mujhe Achche Lagne Lage', '2002'],
#  ['949', 'Henry Fool', '1997'],
#  ['950', 'Explosive Dance', '1998'],
#  ['951', 'Richard Rodgers: The Sweetest Sounds', '2001'],
#  ['952', 'My Favorite Wife', '1940'],
#  ['953', 'Fahrenheit 451', '1966'],
#  ['954', 'I Capture the Castle', '2003'],
#  ['955', 'Rhyme & Reason', '1997'],
#  ['956', 'Blankman', '1994'],
#  ['957', 'Lost in Space: Season 2: Vol. 1', '1966'],
#  ['958', 'World Cup Soccer Highlights: 1966-1974', '2003'],
#  ['959', 'Jay Jay the Jet Plane: Lessons for All Seasons', '2002'],
#  ['960', 'The Unforgiven', '1960'],
#  ['961', 'Love in the Afternoon', '1957'],
#  ['962', 'I Spy', '2002'],
#  ['963', 'A Streetcar Named Desire', '1951'],
#  ['964', 'The Tick: The Entire Series', '2001'],
#  ['965', 'Metropolitan Opera: Puccini: Tosca', '1985'],
#  ['966', 'Young and Dangerous 2', '1996'],
#  ['967', 'Main Hoon Na', '2004'],
#  ['968', 'Dottie Gets Spanked', '1993'],
#  ['969', 'Stripteaser', '1995'],
#  ['970', 'Yesterday Once More', '2004'],
#  ['971', 'Unprecedented: The 2000 Presidential Election', '2002'],
#  ['972', 'Ben Harper: Live at the Hollywood Bowl', '2003'],
#  ['973', 'Dr. Martin Luther King', '1994'],
#  ['974', 'The Devil and Daniel Webster', '1941'],
#  ['975', 'Convict 762', '1997'],
#  ['976', 'Tom and Jerry: Paws for a Holiday', '2003'],
#  ['977', 'Our Lady of the Assassins', '2000'],
#  ['978', 'Yi Yi', '2000'],
#  ['979', 'A Moment of Romance', '1990'],
#  ['980', 'The Swan Princess', '1994'],
#  ['981', 'How I Got into College', '1989'],
#  ['982', 'Dil Chahta Hai', '2001'],
#  ['983', 'Wishful Thinking', '1997'],
#  ['984', 'The Young Lions', '1958'],
#  ['985', 'The Mummy', '1999'],
#  ['986', 'The Trip', '2002'],
#  ['987', "Rescue from Gilligan's Island", '1978'],
#  ['988', 'Operation Pacific', '1951'],
#  ['989', 'The Door in the Floor', '2004'],
#  ['990', 'Meet John Doe', '1941'],
#  ['991', 'Burn Up Excess: Vol. 2: Crimes and Missed Demeanors', '1997'],
#  ['992', 'The Cowboys', '1972'],
#  ['993', 'The Shadow', '1994'],
#  ['994', 'Children of the Corn', '1984'],
#  ['995', 'Dark Town', '2004'],
#  ['996', 'Yojimbo', '1961'],
#  ['997', 'Miracle of the White Stallions', '1963'],
#  ['998', 'Frida: Bonus Material', '2002'],
#  ['999', 'The Favor', '1994'],
#  ['1000', 'Jim Breuer: Hardcore', '2002']]

# %%
fake_user_id = 0

fake_user_ratings= [
    "['13',
  'Lord of the Rings: The Return of the King: Extended Edition: Bonus Material',
  '2003'],"
" ['175', 'Reservoir Dogs', '1992'],
"
]

 ['189', 'Airplane II: The Sequel', '1982'],
 ['199', 'The Deer Hunter', '1978'],
 ['252', 'Stuart Little 2', '2002'],
 ['263', 'Dragon Ball: Tournament Saga', '2001'],
 ['273', 'Taxi', '2004'],
 ['290', 'Harold and Kumar Go to White Castle', '2004'],
 ['299', "Bridget Jones's Diary", '2001'],
 ['316', 'Futurama: Monster Robot Maniac Fun Collection', '1999'],
 ['362', 'The Flintstones in Viva Rock Vegas', '2000'],
 ['457', 'Kill Bill: Vol. 2', '2004'],
 ['468', 'The Matrix: Revolutions', '2003'],


fake_user_rdd =
